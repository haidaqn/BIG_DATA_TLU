# %% [markdown]
# # Thành viên nhóm 3:
# # A42048: Nguyễn Đức Thái
# # A41461: Phương Hải Đăng
# # A38146: Nguyễn Minh Hiếu
# # A40985: Bùi Tiến Dũng

# %% [markdown]
# # 5 giả thuyết
# - Nhiệt độ trung bình toàn cầu tăng cao hơn từ 2020 đến nay
# - Nhiệt độ bán cầu bắc nóng hơn bán cầu nam
# - Các thành phố gần biển có nhiệt độ trung bình thấp hơn, tốc độ gió cao hơn so với các thành phố sâu trong đất liền.
# - Mùa hè nhiều mưa bão nhất
# - Sáng sớm (0h-6h) lạnh hơn so với buổi tối(18h-23h59)

# %% [markdown]
# [Dữ liệu thời tiết](https://drive.google.com/file/d/1XcBudnbdz8f9gq9p3QNTs74JBbP5jGys/view?usp=sharing)
#
# [Dữ liệu thành phố, quốc gia](https://drive.google.com/file/d/1Dsajrwd8YFezVH46APkLU5IwKOixJxQE/view?usp=sharing)

# %% [markdown]
# # Khai báo thư viện

# %%
# !pip install cartopy
# Out:
# Collecting cartopy
#   Downloading Cartopy-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 37.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from cartopy) (1.23.5)
# Requirement already satisfied: matplotlib>=3.4 in /usr/local/lib/python3.10/dist-packages (from cartopy) (3.7.1)
# Requirement already satisfied: shapely>=1.7 in /usr/local/lib/python3.10/dist-packages (from cartopy) (2.0.1)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.10/dist-packages (from cartopy) (23.2)
# Requirement already satisfied: pyshp>=2.1 in /usr/local/lib/python3.10/dist-packages (from cartopy) (2.3.1)
# Requirement already satisfied: pyproj>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from cartopy) (3.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj>=3.1.0->cartopy) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.4->cartopy) (1.16.0)
# Installing collected packages: cartopy
# Successfully installed cartopy-0.22.0

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# # Đọc dữ liệu

# %%
path = "/content/drive/MyDrive/Code/Hoctap/K1N3/BigData/BTL2/"

# %% [markdown]
# ## Dữ liệu về thành phố/thủ đô

# %%
city_df = pd.read_csv(path+"country_city.csv")
city_df.head()
# Out:
#        Country  Latitude  Longitude           Capital  elevation
# 0  Afghanistan   34.5289    69.1725             Kabul     1800.0
# 1      Albania   41.3275    19.8189            Tirane      110.0
# 2      Algeria   36.7525     3.0420           Algiers      186.0
# 3      Andorra   42.5078     1.5211  Andorra la Vella     1045.0
# 4       Angola   -8.8368    13.2343            Luanda       75.0

# %% [markdown]
# ## Dữ liệu thời tiết

# %%
df = pd.read_csv(path+"data_weather.csv")

# %%
df.head()
# Out:
#                time  temperature_2m  relativehumidity_2m  dewpoint_2m  \
# 0  2019-01-01T00:00             2.4                   50         -7.0
# 1  2019-01-01T01:00             2.3                   50         -7.0
# 2  2019-01-01T02:00             2.1                   51         -7.1
# 3  2019-01-01T03:00             2.0                   51         -7.1
# 4  2019-01-01T04:00             2.0                   51         -7.2
#
#    apparent_temperature  precipitation  rain  snowfall  weathercode  \
# 0                  -1.3            0.0   0.0       0.0            2
# 1                  -1.5            0.0   0.0       0.0            2
# 2                  -1.5            0.0   0.0       0.0            3
# 3                  -1.8            0.0   0.0       0.0            3
# 4                  -1.7            0.0   0.0       0.0            3
#
#    pressure_msl  surface_pressure  cloudcover  windspeed_10m  \
# 0        1023.9             822.9          62            5.2
# 1        1023.7             822.6          79            5.2
# 2        1023.7             822.5          85            4.5
# 3        1023.5             822.3          80            5.1
# 4        1022.5             821.5          82            5.1
#
#    winddirection_10m  soil_temperature_0_to_7cm  soil_moisture_0_to_7cm  \
# 0                258                        0.1                   0.212
# 1                258                        0.1                   0.212
# 2                256                        0.0                   0.212
# 3                262                       -0.0                   0.212
# 4                262                       -0.0                   0.212
#
#    is_day   City
# 0       0  Kabul
# 1       0  Kabul
# 2       0  Kabul
# 3       0  Kabul
# 4       0  Kabul

# %% [markdown]
# # Mô tả dữ liệu

# %% [markdown]
# ## Kích thước dữ liệu

# %%
print("Rows data weather:", df.shape[0])
print("Columns data weather:",df.shape[1])
print("Rows data city and country:", city_df.shape[0])
print("Columns data city and country:", city_df.shape[1])
# Out:
# Rows data weather: 7753968
# Columns data weather: 18
# Rows data city and country: 193
# Columns data city and country: 5

# %% [markdown]
# ## Thông tin các thuộc tính

# %% [markdown]
# ### Dữ liệu thời tiết

# %%
df.columns
# Out:
# Index(['time', 'temperature_2m', 'relativehumidity_2m', 'dewpoint_2m',
#        'apparent_temperature', 'precipitation', 'rain', 'snowfall',
#        'weathercode', 'pressure_msl', 'surface_pressure', 'cloudcover',
#        'windspeed_10m', 'winddirection_10m', 'soil_temperature_0_to_7cm',
#        'soil_moisture_0_to_7cm', 'is_day', 'City'],
#       dtype='object')

# %%
# super_data = pd.read_html("https://open-meteo.com/en/docs/historical-weather-api?fbclid=IwAR0RiXQD5SxdhUw7tdSB5ZGkUgVlrnngnYBxHxFylogoOn1nsmh2XRq_K60#latitude=21.0245&longitude=105.8412&hourly=temperature_2m,relativehumidity_2m,dewpoint_2m,apparent_temperature,precipitation,rain,snowfall,weathercode,pressure_msl,surface_pressure,cloudcover,cloudcover_low,cloudcover_mid,cloudcover_high,et0_fao_evapotranspiration,vapor_pressure_deficit,windspeed_10m,winddirection_10m,soil_temperature_0_to_7cm,soil_moisture_0_to_7cm,is_day&daily=&timezone=auto")[2]

# %% [markdown]
# - time: Thời gian tại thời điểm đo đạc
# - temperature_2m: Nhiệt độ không khí ở độ cao 2 mét so với mặt đất (°C)
# - relativehumidity_2m: Độ ẩm tương đối ở độ cao 2 mét so với mặt đất (%)
# - dewpoint_2m: Nhiệt độ điểm sương ở độ cao 2 mét so với mặt đất (°C)
# - apparent_temperature: Nhiệt độ cảm nhận là nhiệt độ cảm nhận kết hợp yếu tố gió, độ ẩm tương đối và bức xạ mặt trời (°C)
# - precipitation: Lượng kết tủa tổng (mưa, tuyết) của giờ trước. Dữ liệu được lưu trữ với độ chính xác 0,1 mm. Nếu dữ liệu lượng mưa được tính tổng thành tổng số tháng, có thể có những sai lệch nhỏ với tổng lượng mưa (mm)
# - rain: Lượng mưa của giờ trước (mm)
# - snowfall: Lượng tuyết rơi của giờ trước tính bằng centimet. Đối với lượng nước tương đương tính bằng milimét, chia cho 0.7 Ví dụ: 7 cm tuyết = 10 mm lượng nước tương đương lượng mưa (cm)
# - weathercode: Điều kiện thời tiết dưới dạng mã thông dịch thời tiết WMO:
#     + Mã 0: Thời tiết trong lành
#     + Mã 1: Mây mỏng hoặc ít mây
#     + Mã 2: Mây xám hoặc có mây
#     + Mã 3: Mây dày
#     + Mã 51: Có mưa
#     + Mã 53: Mưa rào
#     + Mã 55: Mưa đá
#     + Mã 61: Có tuyết
#     + Mã 63: Tuyết rơi
#     + Mã 71: Có sấm sét
#     + Mã 73: Sấm sét và mưa
#     + Mã 65: Sấm sét và tuyết
#     + Mã 75: Sấm sét và mưa đá
# - pressure_msl: Áp suất không khí tại mực nước biển trung bình. Được sử dụng trong khí tượng học (hPa)
# - surface_pressure: Áp suất tại bề mặt. Áp suất bề mặt giảm khi độ cao tăng (hPa)
# - cloudcover: Tổng phần trăm diện tích độ che phủ của mây (%)
# - windspeed_10m: Tốc độ gió ở độ cao 10m so với mặt đất (km/h)
# - winddirection_10m: Hướng gió ở độ cao 10m so với mặt đất (độ) (0 độ bắt đầu từ N, chạy theo chiều kim đồng hồ)
# - soil_temperature_0_to_7cm: Nhiệt độ trung bình của các lớp đất tại độ sâu 0-7m. (°C)
# - soil_moisture_0_to_7cm: Hàm lượng nước trong lòng đất trung bình trong 1 m³ đất tại độ sâu 0-7m (m³)
# - is_day: Là ban ngày hay không
# - City: Thành phố, nơi đo đạc

# %% [markdown]
# ### Dữ liệu thành phố

# %%
city_df.columns
# Out:
# Index(['Country', 'Latitude', 'Longitude', 'Capital', 'elevation'], dtype='object')

# %% [markdown]
# - Country: Quốc gia
# - Latitude: Vĩ độ của thành phố
# - Longitude: Kinh độ của thành phố
# - Capital: Thủ đô/Thành phố lớn nhất (Một vài quốc gia không có thủ đô như Nhật Bản)
# - elevation: Độ cao của thành phố so với mực nước biển

# %% [markdown]
# ## Kiểu dữ liệu
# ### Dữ liệu Thời tiết

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7753968 entries, 0 to 7753967
# Data columns (total 18 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   time                       object
#  1   temperature_2m             float64
#  2   relativehumidity_2m        int64
#  3   dewpoint_2m                float64
#  4   apparent_temperature       float64
#  5   precipitation              float64
#  6   rain                       float64
#  7   snowfall                   float64
#  8   weathercode                int64
#  9   pressure_msl               float64
#  10  surface_pressure           float64
#  11  cloudcover                 int64
#  12  windspeed_10m              float64
#  13  winddirection_10m          int64
#  14  soil_temperature_0_to_7cm  float64
#  15  soil_moisture_0_to_7cm     float64
#  16  is_day                     int64
#  17  City                       object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 1.0+ GB

# %% [markdown]
# - Cột **time** cần có kiểu dữ liệu là *datetime*. Vì khi lưu dữ liệu dưới dạng file *.csv*, kiểu *datetime* được lưu thành *object*
# - **is_day**, **weathercode** là dữ liệu định tính được mã hoá thành số.
# - **City** là dữ liệu định tính
# - Các cột còn lại đều là dữ liệu định lượng

# %%
city_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    193 non-null    object
#  1   Latitude   193 non-null    float64
#  2   Longitude  193 non-null    float64
#  3   Capital    193 non-null    object
#  4   elevation  193 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 7.7+ KB

# %% [markdown]
# Không có vấn đề gì về kiểu dữ liệu.
#
# 2 cột định tính, 3 cột định lượng

# %% [markdown]
# ## Thống kê cơ bản

# %%
df.describe().T
# Out:
#                                count         mean         std      min  \
# temperature_2m             7753968.0    19.928230    9.471677  -38.400
# relativehumidity_2m        7753968.0    71.086740   20.748264    1.000
# dewpoint_2m                7753968.0    13.541707    9.520374  -54.800
# apparent_temperature       7753968.0    20.411876   11.975533  -44.200
# precipitation              7753968.0     0.125596    0.548466    0.000
# rain                       7753968.0     0.123260    0.546969    0.000
# snowfall                   7753968.0     0.001709    0.027879    0.000
# weathercode                7753968.0    11.278378   21.110412    0.000
# pressure_msl               7753968.0  1013.843427    6.686661  939.100
# surface_pressure           7753968.0   971.826154   64.867777  644.000
# cloudcover                 7753968.0    40.266975   34.106508    0.000
# windspeed_10m              7753968.0    11.407699    7.644577    0.000
# winddirection_10m          7753968.0   172.338299  104.837982    0.000
# soil_temperature_0_to_7cm  7753968.0    21.325389   10.155850  -23.100
# soil_moisture_0_to_7cm     7753968.0     0.253785    0.145811   -0.004
# is_day                     7753968.0     0.509118    0.499917    0.000
#
#                                 25%       50%       75%       max
# temperature_2m               14.100    22.800    26.800    51.600
# relativehumidity_2m          60.000    77.000    87.000   100.000
# dewpoint_2m                   7.000    15.100    22.200    31.200
# apparent_temperature         12.400    23.500    30.000    51.400
# precipitation                 0.000     0.000     0.000    41.800
# rain                          0.000     0.000     0.000    41.800
# snowfall                      0.000     0.000     0.000     3.290
# weathercode                   0.000     1.000     3.000    75.000
# pressure_msl               1010.200  1013.300  1017.100  1061.000
# surface_pressure            954.600  1003.100  1010.400  1048.800
# cloudcover                    8.000    33.000    67.000   100.000
# windspeed_10m                 5.800     9.400    15.200   100.100
# winddirection_10m            81.000   165.000   261.000   360.000
# soil_temperature_0_to_7cm    14.700    24.100    28.100    63.600
# soil_moisture_0_to_7cm        0.138     0.268     0.374     0.766
# is_day                        0.000     1.000     1.000     1.000

# %% [markdown]
# - Dựa vào *count*, không có giá trị ở cột nào bị thiếu
# - Dựa vào *min,max*, không có thuộc tính đơn vị % nào có giá trị âm và giá trị vượt quá 100%. Tuy nhiên cột **soil_moisture_0_to_7cm** có min mang giá trị âm. Cần tìm hiểu giá trị này, liệu có phải bất thường?
# - 2 cột **temperature** có độ trải lớn do sự khác biệt về mùa và về vị trí của thành phố vùng cực, vùng xích đạo. Cần kiểm tra xem liệu có phải là giá trị outlier. Trung bình, trung vị gần tương đương nhau. Tuy nhiên độ lệch chuẩn của **apparent_temperature** cao hơn **temperature_2m**, cho thấy dữ liệu của **apparent_temperature** tập trung vào điểm trung bình ít hơn so với **temperature_2m**
# - **relativehumidity_2m**: Dựa vào tứ phân vị thứ nhất (60%) và mean (71), std (20.7), các thành phố đa phần ở những khó xảy ra hạn hán (mức đề phòng hạn hán là ~< 39%).
# - Dựa theo tứ phân vị thứ 3 của các cột **precipitation, rain, snowfall** cho thấy thời tiết đa phần không có mưa hay tuyết.
# - **weathercode, is_day** trên thực tế là giá trị định tính nên các giá trị thống kê trên không có ý nghĩa.
# - **windspeed_10m** có max cao bất thường. Cần kiểm tra liệu có phải outlier hay do bão.

# %%
city_df.describe().T
# Out:
#            count        mean         std       min      25%      50%  \
# Latitude   193.0   18.617681   24.349586  -41.2866   3.8667  15.5518
# Longitude  193.0   21.706083   66.245337 -175.2032  -6.8326  19.8189
# elevation  193.0  385.704663  633.510204  -15.0000  17.0000  62.0000
#
#                 75%        max
# Latitude    39.9199    64.1355
# Longitude   49.8920   179.1991
# elevation  512.0000  3767.0000

# %% [markdown]
# Không có gì bất thường và không có giá trị nào bị null

# %% [markdown]
# # Các vấn đề về dữ liệu
# Chỉ sử dụng dữ liệu thời tiết là chủ yếu, dữ liệu thành phố chỉ hỗ trợ để kiểm định giả thiết và một vài EDA sau này. Vì vậy dữ liệu về quốc gia, thành phố sẽ không phân tích

# %%
def plot_world_map(longs, lats, name = ""):
    fig = plt.figure(figsize=(14, 7))
    ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
    ax.stock_img()
    for lon, lat in zip(longs, lats):
        plt.plot(lon, lat, 'bo', markersize=3.5, transform=ccrs.Geodetic())
    plt.title(name)
    plt.show()

# %% [markdown]
# ## Kiểu dữ liệu

# %%
df.dtypes
# Out:
# time                          object
# temperature_2m               float64
# relativehumidity_2m            int64
# dewpoint_2m                  float64
# apparent_temperature         float64
# precipitation                float64
# rain                         float64
# snowfall                     float64
# weathercode                    int64
# pressure_msl                 float64
# surface_pressure             float64
# cloudcover                     int64
# windspeed_10m                float64
# winddirection_10m              int64
# soil_temperature_0_to_7cm    float64
# soil_moisture_0_to_7cm       float64
# is_day                         int64
# City                          object
# dtype: object

# %% [markdown]
# Không có vấn đề về kiểu dữ liệu.
# Do pandas khi xuất hoặc đọc dữ liệu kiểu datetime sẽ chuyển thành dạng object

# %% [markdown]
# ## Giá trị bị thiếu

# %%
df.isnull().sum()
# Out:
# time                         0
# temperature_2m               0
# relativehumidity_2m          0
# dewpoint_2m                  0
# apparent_temperature         0
# precipitation                0
# rain                         0
# snowfall                     0
# weathercode                  0
# pressure_msl                 0
# surface_pressure             0
# cloudcover                   0
# windspeed_10m                0
# winddirection_10m            0
# soil_temperature_0_to_7cm    0
# soil_moisture_0_to_7cm       0
# is_day                       0
# City                         0
# dtype: int64

# %% [markdown]
# - Có thể thấy không có giá trị nào bị null.
# - Vì kiểu dữ liệu đa phần là kiểu số nên có thể dữ liệu null được thay thế bằng giá trị thay thế hoặc 0. Tuy nhiên khả năng gán 0 cho giá trị null khó có thể xảy ra do 0 cũng là giá trị có ý nghĩa, vì vậy người hoặc máy nhập liệu sẽ không gán 0 thay cho giá trị null. Còn lại thông thường sẽ chọn 1 giá trị ngoài khoảng giá trị của các cột (chẳng hạn cột về % từ 0-100, null sẽ thay thế bằng -1), tuy nhiên khi describe không thấy xuất hiện giá trị min hay max nào bất thường.
#
# - Cần lưu ý **time** liệu có mang 1 giá trị nào thay thế giá trị null (Vì đang là kiểu object) Nếu có lỗi trong quá trình chuyển thành datetime thì đó chính là giá trị thay thế null
# - Cột **City** không thể null do trong quá trình nối bảng đều có thêm giá trị của các thành phố

# %% [markdown]
# ## Trùng lặp
# Cần kiểm tra xem cùng 1 thành phố, liệu có thời gian nào bi trùng nhau hay không

# %%
df.duplicated(subset=['City','time'], keep=False).sum()
# Out:
# 0

# %% [markdown]
# Kiểm tra khi bỏ cột **time**

# %%
df.drop(columns=['time']).duplicated(keep=False).sum()
# Out:
# 28

# %% [markdown]
# Xuất hiện 10 giá trị bị duplicate

# %%
df_dup = df[df.drop(columns=['time']).duplicated(keep=False)]

# %%
df_dup
# Out:
#                      time  temperature_2m  relativehumidity_2m  dewpoint_2m  \
# 298005   2020-11-29T21:00             1.7                   81         -1.2
# 298006   2020-11-29T22:00             1.7                   81         -1.2
# 298347   2020-12-14T03:00            -0.3                   87         -2.2
# 298348   2020-12-14T04:00            -0.3                   87         -2.2
# 637001   2022-12-02T17:00            -4.9                   89         -6.4
# 637002   2022-12-02T18:00            -4.9                   89         -6.4
# 1817535  2020-02-05T15:00            -6.8                   22        -25.1
# 1817536  2020-02-05T16:00            -6.8                   22        -25.1
# 2773684  2019-03-06T04:00            23.7                   94         22.6
# 2773685  2019-03-06T05:00            23.7                   94         22.6
# 3616634  2019-02-03T02:00           -13.0                   68        -17.7
# 3616635  2019-02-03T03:00           -13.0                   68        -17.7
# 3641237  2021-11-24T05:00            -5.9                   72        -10.1
# 3641238  2021-11-24T06:00            -5.9                   72        -10.1
# 4468564  2020-01-12T04:00             7.1                   85          4.8
# 4468565  2020-01-12T05:00             7.1                   85          4.8
# 4750084  2020-01-24T04:00            28.7                   80         24.9
# 4750085  2020-01-24T05:00            28.7                   80         24.9
# 5022727  2019-01-31T07:00            -9.5                   88        -11.1
# 5022728  2019-01-31T08:00            -9.5                   88        -11.1
# 5039717  2021-01-08T05:00            -6.4                   86         -8.3
# 5039719  2021-01-08T07:00            -6.4                   86         -8.3
# 5726810  2021-06-28T02:00            26.7                   78         22.6
# 5726812  2021-06-28T04:00            26.7                   78         22.6
# 6645361  2020-11-11T01:00             5.8                   92          4.6
# 6645362  2020-11-11T02:00             5.8                   92          4.6
# 7595282  2019-03-26T02:00            18.6                   85         16.0
# 7595283  2019-03-26T03:00            18.6                   85         16.0
#
#          apparent_temperature  precipitation  rain  snowfall  weathercode  \
# 298005                   -1.7            0.0   0.0       0.0            3
# 298006                   -1.7            0.0   0.0       0.0            3
# 298347                   -3.0            0.0   0.0       0.0            3
# 298348                   -3.0            0.0   0.0       0.0            3
# 637001                   -9.1            0.0   0.0       0.0            3
# 637002                   -9.1            0.0   0.0       0.0            3
# 1817535                 -13.5            0.0   0.0       0.0            0
# 1817536                 -13.5            0.0   0.0       0.0            0
# 2773684                  28.4            0.0   0.0       0.0            0
# 2773685                  28.4            0.0   0.0       0.0            0
# 3616634                 -17.4            0.0   0.0       0.0            0
# 3616635                 -17.4            0.0   0.0       0.0            0
# 3641237                  -9.8            0.0   0.0       0.0            0
# 3641238                  -9.8            0.0   0.0       0.0            0
# 4468564                   5.1            0.0   0.0       0.0            0
# 4468565                   5.1            0.0   0.0       0.0            0
# 4750084                  32.0            0.0   0.0       0.0            0
# 4750085                  32.0            0.0   0.0       0.0            0
# 5022727                 -14.3            0.0   0.0       0.0            3
# 5022728                 -14.3            0.0   0.0       0.0            3
# 5039717                 -11.3            0.0   0.0       0.0            3
# 5039719                 -11.3            0.0   0.0       0.0            3
# 5726810                  27.9            0.0   0.0       0.0            1
# 5726812                  27.9            0.0   0.0       0.0            1
# 6645361                   3.3            0.0   0.0       0.0            3
# 6645362                   3.3            0.0   0.0       0.0            3
# 7595282                  20.3            0.0   0.0       0.0            3
# 7595283                  20.3            0.0   0.0       0.0            3
#
#          pressure_msl  surface_pressure  cloudcover  windspeed_10m  \
# 298005         1026.0             907.4         100            7.1
# 298006         1026.0             907.4         100            7.1
# 298347         1024.0             904.8         100            1.8
# 298348         1024.0             904.8         100            1.8
# 637001         1033.5            1004.3         100            8.7
# 637002         1033.5            1004.3         100            8.7
# 1817535        1032.9            1027.6           0           18.7
# 1817536        1032.9            1027.6           0           18.7
# 2773684        1010.8            1004.5           0            4.0
# 2773685        1010.8            1004.5           0            4.0
# 3616634        1021.9             925.2           0            4.7
# 3616635        1021.9             925.2           0            4.7
# 3641237        1018.1             924.2           0            4.3
# 3641238        1018.1             924.2           0            4.3
# 4468564        1028.2            1020.1           0            4.7
# 4468565        1028.2            1020.1           0            4.7
# 4750084        1007.9            1007.3           7           23.1
# 4750085        1007.9            1007.3           7           23.1
# 5022727        1008.4            1004.9         100           10.3
# 5022728        1008.4            1004.9         100           10.3
# 5039717        1017.7            1014.2         100           12.8
# 5039719        1017.7            1014.2         100           12.8
# 5726810        1016.8            1016.0          36           27.4
# 5726812        1016.8            1016.0          36           27.4
# 6645361        1031.7            1029.1         100            8.2
# 6645362        1031.7            1029.1         100            8.2
# 7595282        1015.9            1014.7         100            2.3
# 7595283        1015.9            1014.7         100            2.3
#
#          winddirection_10m  soil_temperature_0_to_7cm  soil_moisture_0_to_7cm  \
# 298005                 221                        0.7                   0.176
# 298006                 221                        0.7                   0.176
# 298347                 217                        0.3                   0.220
# 298348                 217                        0.3                   0.220
# 637001                 355                       -0.2                   0.336
# 637002                 355                       -0.2                   0.336
# 1817535                326                       -1.9                   0.348
# 1817536                326                       -1.9                   0.348
# 2773684                333                       24.5                   0.187
# 2773685                333                       24.5                   0.187
# 3616634                 67                       -0.4                   0.333
# 3616635                 67                       -0.4                   0.333
# 3641237                 85                        0.1                   0.352
# 3641238                 85                        0.1                   0.352
# 4468564                356                        5.9                   0.333
# 4468565                356                        5.9                   0.333
# 4750084                273                       29.9                   0.000
# 4750085                273                       29.9                   0.000
# 5022727                 29                        0.2                   0.210
# 5022728                 29                        0.2                   0.210
# 5039717                344                        1.3                   0.237
# 5039719                344                        1.3                   0.237
# 5726810                 93                       27.9                   0.000
# 5726812                 93                       27.9                   0.000
# 6645361                232                        6.5                   0.390
# 6645362                232                        6.5                   0.390
# 7595282                 51                       19.4                   0.371
# 7595283                 51                       19.4                   0.371
#
#          is_day                                               City
# 298005        0                                            Yerevan
# 298006        0                                            Yerevan
# 298347        0                                            Yerevan
# 298348        0                                            Yerevan
# 637001        0                                              Minsk
# 637002        0                                              Minsk
# 1817535       1                                          Pyongyang
# 1817536       1                                          Pyongyang
# 2773684       0                                            Conakry
# 2773685       0                                            Conakry
# 3616634       0                                            Bishkek
# 3616635       0                                            Bishkek
# 3641237       0                                            Bishkek
# 3641238       0                                            Bishkek
# 4468564       0                                        Monte Carlo
# 4468565       0                                        Monte Carlo
# 4750084       0  no official capital; government offices in Yar...
# 4750085       0  no official capital; government offices in Yar...
# 5022727       0                                               Oslo
# 5022728       0                                               Oslo
# 5039717       0                                               Oslo
# 5039719       0                                               Oslo
# 5726810       0                                         Basseterre
# 5726812       0                                         Basseterre
# 6645361       0                                          Stockholm
# 6645362       0                                          Stockholm
# 7595282       0                                              Hanoi
# 7595283       0                                              Hanoi

# %% [markdown]
# Có 5 cặp có thời gian gần nhau (cách nhau 1h) và cùng thành phố. Số liệu có thể giống nhau do:
# + Số liệu 2 giờ thực sự giống nhau
# + Bản ghi có thời gian muộn hơn chưa kịp update số liệu nên đã fill method = "bfill"
#
# Kiểm tra trường hợp đầu tiên: **Số liệu giống nhau thật hay không**

# %%
df.loc[4750082:4750087].T
# Out:
#                                                                      4750082  \
# time                                                        2020-01-24T02:00
# temperature_2m                                                          28.8
# relativehumidity_2m                                                       79
# dewpoint_2m                                                             24.8
# apparent_temperature                                                    32.1
# precipitation                                                            0.0
# rain                                                                     0.0
# snowfall                                                                 0.0
# weathercode                                                                0
# pressure_msl                                                          1009.1
# surface_pressure                                                      1008.5
# cloudcover                                                                 1
# windspeed_10m                                                           22.3
# winddirection_10m                                                        268
# soil_temperature_0_to_7cm                                               29.9
# soil_moisture_0_to_7cm                                                   0.0
# is_day                                                                     0
# City                       no official capital; government offices in Yar...
#
#                                                                      4750083  \
# time                                                        2020-01-24T03:00
# temperature_2m                                                          28.7
# relativehumidity_2m                                                       80
# dewpoint_2m                                                             24.9
# apparent_temperature                                                    32.0
# precipitation                                                            0.0
# rain                                                                     0.0
# snowfall                                                                 0.0
# weathercode                                                                0
# pressure_msl                                                          1008.3
# surface_pressure                                                      1007.7
# cloudcover                                                                 2
# windspeed_10m                                                           23.0
# winddirection_10m                                                        270
# soil_temperature_0_to_7cm                                               29.9
# soil_moisture_0_to_7cm                                                   0.0
# is_day                                                                     0
# City                       no official capital; government offices in Yar...
#
#                                                                      4750084  \
# time                                                        2020-01-24T04:00
# temperature_2m                                                          28.7
# relativehumidity_2m                                                       80
# dewpoint_2m                                                             24.9
# apparent_temperature                                                    32.0
# precipitation                                                            0.0
# rain                                                                     0.0
# snowfall                                                                 0.0
# weathercode                                                                0
# pressure_msl                                                          1007.9
# surface_pressure                                                      1007.3
# cloudcover                                                                 7
# windspeed_10m                                                           23.1
# winddirection_10m                                                        273
# soil_temperature_0_to_7cm                                               29.9
# soil_moisture_0_to_7cm                                                   0.0
# is_day                                                                     0
# City                       no official capital; government offices in Yar...
#
#                                                                      4750085  \
# time                                                        2020-01-24T05:00
# temperature_2m                                                          28.7
# relativehumidity_2m                                                       80
# dewpoint_2m                                                             24.9
# apparent_temperature                                                    32.0
# precipitation                                                            0.0
# rain                                                                     0.0
# snowfall                                                                 0.0
# weathercode                                                                0
# pressure_msl                                                          1007.9
# surface_pressure                                                      1007.3
# cloudcover                                                                 7
# windspeed_10m                                                           23.1
# winddirection_10m                                                        273
# soil_temperature_0_to_7cm                                               29.9
# soil_moisture_0_to_7cm                                                   0.0
# is_day                                                                     0
# City                       no official capital; government offices in Yar...
#
#                                                                      4750086  \
# time                                                        2020-01-24T06:00
# temperature_2m                                                          28.7
# relativehumidity_2m                                                       80
# dewpoint_2m                                                             24.9
# apparent_temperature                                                    32.0
# precipitation                                                            0.0
# rain                                                                     0.0
# snowfall                                                                 0.0
# weathercode                                                                0
# pressure_msl                                                          1007.9
# surface_pressure                                                      1007.3
# cloudcover                                                                13
# windspeed_10m                                                           23.0
# winddirection_10m                                                        271
# soil_temperature_0_to_7cm                                               29.9
# soil_moisture_0_to_7cm                                                   0.0
# is_day                                                                     0
# City                       no official capital; government offices in Yar...
#
#                                                                      4750087
# time                                                        2020-01-24T07:00
# temperature_2m                                                          28.8
# relativehumidity_2m                                                       79
# dewpoint_2m                                                             24.9
# apparent_temperature                                                    31.9
# precipitation                                                            0.0
# rain                                                                     0.0
# snowfall                                                                 0.0
# weathercode                                                                0
# pressure_msl                                                          1008.5
# surface_pressure                                                      1007.9
# cloudcover                                                                20
# windspeed_10m                                                           23.8
# winddirection_10m                                                        272
# soil_temperature_0_to_7cm                                               29.9
# soil_moisture_0_to_7cm                                                   0.0
# is_day                                                                     1
# City                       no official capital; government offices in Yar...

# %% [markdown]
# Có thể thấy các giá trị của các giờ liên tiếp gần như là giống nhau. Vì vậy trường hợp số liệu giống nhau có thể xảy ra
#
# **KẾT LUẬN: Không có giá trị nào bị trùng lặp**
#
# Nhận thấy điều bất thường ở tên thành phố. Kiểm tra độ dài tên thành phố ở phần Giá trị bất thường

# %% [markdown]
# ## Giá trị ngoại lai & bất thường

# %%
def IQR_Outlier(data):
    '''
    Nhận dữ liệu 1 cột, trả về 2 giá trị minimum và maximum của cột đó
    Sử dụng để kiểm tra giá trị ngoại biên
    '''
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    return (Q1 - 1.5 * IQR, Q3 + 1.5 * IQR)

# %% [markdown]
# ### apparent_temperature

# %%
min_atemp = df.apparent_temperature.min()
max_atemp = df.apparent_temperature.max()
min_atemp, max_atemp
# Out:
# (-44.2, 51.4)

# %%
df[['City','time']][df.apparent_temperature == min_atemp]
# Out:
#                 City              time
# 4535334  Ulaanbaatar  2023-01-24T06:00

# %% [markdown]
# Vào thời gian trên ở Ulaanbaata (Mông Cổ) đúng là đã ghi nhận mức nhiệt thấp dưới -44 độ

# %%
df[['City','time']][df.apparent_temperature == max_atemp]
# Out:
#             City              time
# 3187716  Baghdad  2020-07-29T12:00

# %%
out_atemp = IQR_Outlier(df.apparent_temperature)
out_atemp
# Out:
# (-14.000000000000002, 56.400000000000006)

# %%
city_out_low_atemp = df.City[df.apparent_temperature < out_atemp[0]].value_counts().keys()
city_out_high_atemp = df.City[df.apparent_temperature > out_atemp[1]].value_counts().keys()

# %%
city_out_low_atemp, city_out_high_atemp
# Out:
# (Index(['Ulaanbaatar', 'Nur Sultan', 'Ottawa', 'Moscow', 'Kabul', 'Minsk',
#         'Bishkek', 'Pyongyang', 'Reykjavik', 'Helsinki', 'Oslo', 'Tallinn',
#         'Riga', 'Vilnius', 'Kiev', 'Seoul', 'Yerevan', 'Beijing', 'Tashkent',
#         'Dushanbe', 'Stockholm', 'Warsaw', 'Sofia', 'Vaduz', 'Prague', 'Berlin',
#         'Sarajevo', 'Chisinau', 'Washington D.C.', 'Skopje', 'Ankara', 'Tehran',
#         'Ashgabat', 'Bucharest', 'Copenhagen', 'Andorra la Vella', 'Belgrade',
#         'Luxembourg', 'San Marino', 'Amsterdam; The Hague (seat of government)',
#         'Berne', 'Podgorica', 'Thimphu', 'Budapest', 'Ljubljana', 'Brussels',
#         'Vienna', 'Bratislava', 'Baku', 'Madrid'],
#        dtype='object'),
#  Index([], dtype='object'))

# %% [markdown]
# Chỉ có các thành phố có nhiệt độ thấp hơn -14 độ.

# %%
lat_out_low_atemp = city_df[city_df.Capital.isin(city_out_low_atemp)]['Latitude']
long_out_low_atemp = city_df[city_df.Capital.isin(city_out_low_atemp)]['Longitude']

plot_world_map(long_out_low_atemp, lat_out_low_atemp,"Những nơi có nhiệt độ thấp hơn -14*C")

# %% [markdown]
# Có thể thấy các vĩ độ của các thành phố có nhiệt độ thấp hơn -14 độ đều ở bán cầu bắc, ao gồm các vùng có nhiệt độ thấp: ôn đới, hàn đới, các vùng ở núi cao.
#
# Trên thực tế, ghi nhận nhiều nơi có nhiệt độ rất thấp.
#
# **KẾT LUẬN: apparent_temperature không bị outlier**

# %% [markdown]
# ### relativehumidity_2m

# %%
min_rh = df.relativehumidity_2m.min()
out_rh = IQR_Outlier(df.relativehumidity_2m)
out_rh[0], min_rh
# Out:
# (19.5, 1)

# %%
city_out_low_rh = df.City[df.relativehumidity_2m < out_rh[0]].value_counts().keys()
city_out_low_rh
# Out:
# Index(['Riyadh', 'Khartoum', 'Baghdad', 'N’Djamena', 'Niamey', 'Ouagadougou',
#        'Windhoek', 'Bamako', 'Sanaa', 'Kuwait City', 'Tehran', 'Ashgabat',
#        'Damascus', 'Kabul', 'Beijing', 'Abuja', 'Gaborone', 'Madrid', 'Cairo',
#        'Juba', 'La Paz (administrative); Sucre (judicial)', 'Tashkent',
#        'Amman', 'Maseru', 'Ulaanbaatar', 'Dushanbe', 'Mexico City', 'Bissau',
#        'Yerevan', 'Ankara', 'New Delhi', 'Bangui', 'Nouakchott', 'Harare',
#        'Islamabad', 'Jerusalem*', 'Lusaka', 'Nicosia', 'Addis Ababa', 'Asmara',
#        'Bishkek', 'Brasilia', 'Santiago', 'Nur Sultan', 'Abu Dhabi',
#        'Nay Pyi Taw', 'Canberra', 'Dar es Salaam; Dodoma (legislative)',
#        'Tripoli', 'Tbilisi', 'Doha', 'Mbabane', 'Athens', 'Banjul', 'Skopje',
#        'Nairobi', 'Lilongwe', 'Algiers', 'Pyongyang', 'Djibouti', 'Tunis',
#        'Antananarivo', 'Seoul', 'Beirut', 'Dakar', 'Bucharest', 'Chisinau',
#        'Tegucigalpa', 'Guatemala City', 'Kathmandu', 'Maputo', 'Asuncion',
#        'San Salvador', 'Andorra la Vella',
#        'Pretoria (administrative); Cape Town (legislative); Bloemfontein (judiciary)',
#        'Yaounde', 'Vienna', 'Berlin', 'Rabat', 'Paris', 'Belgrade', 'Muscat',
#        'Lisbon', 'Oslo', 'Washington D.C.', 'Budapest', 'Thimphu', 'Managua',
#        'Reykjavik', 'Vientiane', 'Buenos Aires', 'Prague', 'Dhaka', 'Ottawa',
#        'Bratislava', 'Tirane', 'Podgorica', 'Brussels', 'Sofia',
#        'Monte Carlo'],
#       dtype='object')

# %%
lat_out_low_rh = city_df[city_df.Capital.isin(city_out_low_rh)]['Latitude']
long_out_low_rh = city_df[city_df.Capital.isin(city_out_low_rh)]['Longitude']
plot_world_map(long_out_low_rh, lat_out_low_rh, name = "Các nơi độ ẩm tương đối thấp hơn 20%");

# %% [markdown]
# Thực tế, độ ẩm tương đối có thể xuống dưới 20% trong điều kiện khắc nghiệt như sa mạc hoặc vùng khí hậu rất khô (châu Âu, các vùng ôn đới khí hậu đa phần là khô). Một vài nguyên nhân khiến độ ẩm tương đối thấp:
#
# - Mùa đông, độ ẩm thường giảm do lượng nhiệt độ thấp, hơi nước trong không khí giảm.
# - Mùa hè khi nhiệt độ tăng mạnh, sự bốc hơi nước nhanh
# - Các vùng khí hậu khô hạn như sa mạc
# - Ngoài ra có thể do địa hình, chẳng hạn như gió Lào ở Việt Nam
#
# **KẾT LUẬN: Không có giá trị relativehumidity nào bất thường**

# %% [markdown]
# ### soil_moisture_0_to_7cm

# %%
df.City[df.soil_moisture_0_to_7cm < 0].value_counts()
# Out:
# Nouakchott    65
# Name: City, dtype: int64

# %% [markdown]
# Theo tìm hiểu: Độ ẩm đất mang giá trị không có nghĩa là độ ẩm thực sự âm. Thay vào đó, giá trị âm thường được sử dụng để chỉ ra rằng đất khô hơn mức cân bằng hoặc mức độ ẩm tối thiểu.
#
# Nouakchott nằm trong những nơi khô cằn nhất trên Trái Đất, là một trong những thành phố lớn nhất tại sa mạc Sahara. Đất ở đây có thể rất khô, và do đó độ ẩm đất có thể cho thấy giá trị âm.

# %%
plt.figure(figsize=(8,3))
plt.boxplot(df.soil_moisture_0_to_7cm, vert=False)
plt.xlabel("m3")
plt.title("Biểu đồ hộp của soil_moisture_0_to_7cm")
plt.show()

# %%
out_sm07 = IQR_Outlier(df.soil_moisture_0_to_7cm)
df_out_sm07 = df[df.soil_moisture_0_to_7cm > out_sm07[1]]
df_out_sm07.City.value_counts()
# Out:
# Amsterdam; The Hague (seat of government)    814
# Name: City, dtype: int64

# %% [markdown]
# Chỉ Amsterdam có giá trị soil_moisture_0_to_7cm cao bất thường.
#
# Tuy nhiên Amsterdam là một thành phố với hệ thống kênh rạch dày đặc, nhiều nước. Vì vậy nên soil_moisture_0_to_7cm cao hơn các nơi khác không có gì lạ

# %% [markdown]
# **KẾT LUẬN: soil_moisture_0_to_7cm không có gì bất thường**

# %% [markdown]
# ### soil_temperature_0_to_7cm
# Mặt đất thoát nhiệt chậm hơn so với không khí, vì vậy chỉ cần kiểm tra các giá trị outlier

# %%
plt.figure(figsize=(8,3))
plt.boxplot(df.soil_temperature_0_to_7cm, vert=False)
plt.xlabel("*C")
plt.title("Biểu đồ hộp của soil_temperature_0_to_7cm")
plt.show()

# %% [markdown]
# Nhiệt độ mặt đất trung bình từ dưới -20 độ vẫn có thể xảy ra do nhiệt độ không khí có thể xuống thấp hơn. Mặt đất thường có xu hướng nóng và giữ nhiệt hơn so với bề mặt khí quyển  do mặt đất và khí quyển có khả năng hấp thụ và phản xạ ánh sáng mặt trời khác nhau.
#
# **KẾT LUẬN: Không có soil_temperature_0_to_7cm nào bất thường**

# %% [markdown]
# ### City
# Một số tên chứa cả các mô tả của thành phố

# %%
for index, row in city_df.iterrows():
    country = row["Country"]
    city = row["Capital"]
    longitude = row["Longitude"]
    latitude = row["Latitude"]
    print(index, "{:<25} {:<30} {:<12} {:<12}".format(country, city, longitude, latitude))
# Out:
# 0 Afghanistan               Kabul                          69.1725      34.5289
# 1 Albania                   Tirane                         19.8189      41.3275
# 2 Algeria                   Algiers                        3.042        36.7525
# 3 Andorra                   Andorra la Vella               1.5211       42.5078
# 4 Angola                    Luanda                         13.2343      -8.8368
# 5 Antigua and Barbuda       Saint John’s                   -61.8457     17.1172
# 6 Argentina                 Buenos Aires                   -58.4004     -34.6051
# 7 Armenia                   Yerevan                        44.5146      40.182
# 8 Australia                 Canberra                       149.1281     -35.2835
# 9 Austria                   Vienna                         16.3707      48.2064
# 10 Azerbaijan                Baku                           49.892       40.3777
# 11 Bahamas                   Nassau                         -77.3431     25.0582
# 12 Bahrain                   Manama                         50.5832      26.2154
# 13 Bangladesh                Dhaka                          90.4074      23.7104
# 14 Barbados                  Bridgetown                     -59.6167     13.1
# 15 Belarus                   Minsk                          27.5667      53.9
# 16 Belgium                   Brussels                       4.3499       50.8467
# 17 Belize                    Belmopan                       -88.7667     17.25
# 18 Benin                     Porto-Novo                     2.4183       6.3654
# 19 Bhutan                    Thimphu                        89.6419      27.4661
# 20 Bolivia                   La Paz (administrative); Sucre (judicial) -68.15       -16.5
# 21 Bosnia and Herzegovina    Sarajevo                       18.3564      43.8486
# 22 Botswana                  Gaborone                       25.9086      -24.6545
# 23 Brazil                    Brasilia                       -47.9297     -15.7797
# 24 Brunei                    Bandar Seri Begawan            114.9481     4.9403
# 25 Bulgaria                  Sofia                          23.3242      42.6975
# 26 Burkina Faso              Ouagadougou                    -1.5383      12.3642
# 27 Burundi                   Gitega                         29.3644      -3.3822
# 28 Cape Verde                Praia                          -23.5087     14.9215
# 29 Cambodia                  Phnom Penh                     104.916      11.5625
# 30 Cameroon                  Yaounde                        11.5167      3.8667
# 31 Canada                    Ottawa                         -75.698      45.4166
# 32 Central Africa            Bangui                         18.555       4.3612
# 33 Chad                      N’Djamena                      15.0444      12.1067
# 34 Chile                     Santiago                       -70.6483     -33.4569
# 35 China                     Beijing                        116.3972     39.9075
# 36 Colombia                  Bogota                         -74.0818     4.6097
# 37 Comoros                   Moroni                         43.2551      -11.7022
# 38 Congo                     Brazzaville                    15.2832      -4.2658
# 39 Costa Rica                San Jose                       -84.0807     9.9278
# 40 Ivory Coast               Yamoussoukro (official); Abidjan (de facto) -4.0268      5.3453
# 41 Croatia                   Zagreb                         15.978       45.8144
# 42 Cuba                      Havana                         -82.3785     23.1195
# 43 Cyprus                    Nicosia                        33.3669      35.1595
# 44 Czechia                   Prague                         14.4208      50.088
# 45 North Korea               Pyongyang                      125.7543     39.0339
# 46 Congo (Dem. Republic)     Kinshasa                       15.3136      -4.3276
# 47 Denmark                   Copenhagen                     12.5655      55.6759
# 48 Djibouti                  Djibouti                       43.1447      11.5877
# 49 Dominica                  Roseau                         -61.3881     15.3017
# 50 Dominican Republic        Santo Domingo                  -69.9018     18.4896
# 51 Ecuador                   Quito                          -78.525      -0.2299
# 52 Egypt                     Cairo                          31.2394      30.0392
# 53 El Salvador               San Salvador                   -89.1872     13.6894
# 54 Equatorial Guinea         Malabo                         8.7833       3.75
# 55 Eritrea                   Asmara                         38.9333      15.3333
# 56 Estonia                   Tallinn                        24.7535      59.437
# 57 Ethiopia                  Addis Ababa                    38.7469      9.025
# 58 Fiji                      Suva                           178.4415     -18.1416
# 59 Finland                   Helsinki                       24.9402      60.1692
# 60 France                    Paris                          2.3488       48.8534
# 61 Gabon                     Libreville                     9.4537       0.3925
# 62 Gambia                    Banjul                         -16.6794     13.4531
# 63 Georgia                   Tbilisi                        44.8337      41.6941
# 64 Germany                   Berlin                         13.4105      52.5244
# 65 Ghana                     Accra                          -0.1969      5.556
# 66 Greece                    Athens                         23.749       37.9534
# 67 Grenada                   Saint George’s                 -61.7485     12.0564
# 68 Guatemala                 Guatemala City                 -90.5307     14.6127
# 69 Guinea                    Conakry                        -13.6476     9.5716
# 70 Guinea-Bissau             Bissau                         -15.5977     11.8636
# 71 Guyana                    Georgetown                     -58.1553     6.8045
# 72 Haiti                     Port-au-Prince                 -72.335      18.5392
# 73 Honduras                  Tegucigalpa                    -87.2068     14.0818
# 74 Hungary                   Budapest                       19.0399      47.498
# 75 Iceland                   Reykjavik                      -21.8954     64.1355
# 76 India                     New Delhi                      77.2167      28.6667
# 77 Indonesia                 Jakarta                        106.8416     -6.2118
# 78 Iran                      Tehran                         51.4215      35.6944
# 79 Iraq                      Baghdad                        44.4009      33.3406
# 80 Ireland                   Dublin                         -6.2489      53.3331
# 81 Israel                    Jerusalem*                     35.2163      31.769
# 82 Italy                     Rome                           12.4811      41.8947
# 83 Jamaica                   Kingston                       -76.7936     17.997
# 84 Japan                     Tokyo                          139.6917     35.6895
# 85 Jordan                    Amman                          35.945       31.9552
# 86 Kazakhstan                Nur Sultan                     71.446       51.1801
# 87 Kenya                     Nairobi                        36.8167      -1.2833
# 88 Kiribati                  Tarawa Atoll                   172.9813     1.3272
# 89 Kuwait                    Kuwait City                    47.9783      29.3697
# 90 Kyrgyzstan                Bishkek                        74.59        42.87
# 91 Laos                      Vientiane                      102.6        17.9667
# 92 Latvia                    Riga                           24.1059      56.946
# 93 Lebanon                   Beirut                         35.4833      33.9
# 94 Lesotho                   Maseru                         27.4833      -29.3167
# 95 Liberia                   Monrovia                       -10.7969     6.3005
# 96 Libya                     Tripoli                        13.1875      32.8752
# 97 Liechtenstein             Vaduz                          9.5215       47.1415
# 98 Lithuania                 Vilnius                        25.2798      54.6892
# 99 Luxembourg                Luxembourg                     6.13         49.6117
# 100 Madagascar                Antananarivo                   47.5361      -18.9137
# 101 Malawi                    Lilongwe                       33.7873      -13.9669
# 102 Malaysia                  Kuala Lumpur                   101.6865     3.1412
# 103 Maldives                  Male                           73.5089      4.1748
# 104 Mali                      Bamako                         -8.0         12.65
# 105 Malta                     Valletta                       14.5147      35.8997
# 106 Marshall Islands          Majuro                         171.3803     7.0897
# 107 Mauritania                Nouakchott                     -15.9785     18.0858
# 108 Mauritius                 Port Louis                     57.4989      -20.1619
# 109 Mexico                    Mexico City                    -99.1419     19.4273
# 110 Micronesia                Palikir                        158.1588     6.9174
# 111 Monaco                    Monte Carlo                    7.4167       43.7333
# 112 Mongolia                  Ulaanbaatar                    106.8832     47.9077
# 113 Montenegro                Podgorica                      19.2636      42.4411
# 114 Morocco                   Rabat                          -6.8326      34.0133
# 115 Mozambique                Maputo                         32.5892      -25.9653
# 116 Myanmar                   Nay Pyi Taw                    96.1297      19.745
# 117 Namibia                   Windhoek                       17.0832      -22.5594
# 118 Nauru                     no official capital; government offices in Yaren District 166.9112     -0.5308
# 119 Nepal                     Kathmandu                      85.3206      27.7017
# 120 Netherlands               Amsterdam; The Hague (seat of government) 4.8897       52.374
# 121 New Zealand               Wellington                     174.7756     -41.2866
# 122 Nicaragua                 Managua                        -86.2504     12.1328
# 123 Niger                     Niamey                         2.1098       13.5137
# 124 Nigeria                   Abuja                          7.4898       9.0574
# 125 Norway                    Oslo                           10.7461      59.9127
# 126 Oman                      Muscat                         58.5922      23.6139
# 127 Pakistan                  Islamabad                      73.0594      33.7035
# 128 Palau                     Melekeok                       134.4789     7.3426
# 129 Panama                    Panama City                    -79.5196     8.9958
# 130 Papua New Guinea          Port Moresby                   147.1797     -9.4431
# 131 Paraguay                  Asuncion                       -57.6359     -25.3007
# 132 Peru                      Lima                           -77.0282     -12.0432
# 133 Philippines               Manila                         120.9822     14.6042
# 134 Poland                    Warsaw                         21.0118      52.2298
# 135 Portugal                  Lisbon                         -9.1399      38.7169
# 136 Qatar                     Doha                           51.5245      25.2747
# 137 South Korea               Seoul                          126.9778     37.5683
# 138 Moldova                   Chisinau                       28.8575      47.0056
# 139 Romania                   Bucharest                      26.1043      44.4328
# 140 Russia                    Moscow                         37.6218      55.755
# 141 Rwanda                    Kigali                         30.0579      -1.9474
# 142 Saint Kitts and Nevis     Basseterre                     -62.7261     17.2948
# 143 Saint Lucia               Castries                       -60.991      14.006
# 144 Saint Vincent and the Grenadines Kingstown                      -61.2248     13.1587
# 145 Samoa                     Apia                           -171.7667    -13.8333
# 146 San Marino                San Marino                     12.45        43.9333
# 147 Sao Tome and Principe     Sao Tome                       6.7273       0.3365
# 148 Saudi Arabia              Riyadh                         46.7096      24.6905
# 149 Senegal                   Dakar                          -17.4441     14.6937
# 150 Serbia                    Belgrade                       20.4633      44.8176
# 151 Seychelles                Victoria                       55.45        -4.6167
# 152 Sierra Leone              Freetown                       -13.2299     8.484
# 153 Singapore                 Singapore                      103.8501     1.2897
# 154 Slovakia                  Bratislava                     17.1067      48.1482
# 155 Slovenia                  Ljubljana                      14.5051      46.0511
# 156 Solomon Islands           Honiara                        159.95       -9.4333
# 157 Somalia                   Mogadishu                      45.3435      2.0416
# 158 South Africa              Pretoria (administrative); Cape Town (legislative); Bloemfontein (judiciary) 18.4232      -33.9258
# 159 South Sudan               Juba                           31.5825      4.8517
# 160 Spain                     Madrid                         -3.7026      40.4165
# 161 Sri Lanka                 Colombo; Sri Jayewardenepura Kotte (legislative) 79.8478      6.9319
# 162 Sudan                     Khartoum                       32.5324      15.5518
# 163 Suriname                  Paramaribo                     -55.1668     5.8664
# 164 Eswatini                  Mbabane                        31.1333      -26.3167
# 165 Sweden                    Stockholm                      18.0649      59.3326
# 166 Switzerland               Berne                          7.4474       46.9481
# 167 Syria                     Damascus                       36.3084      33.5086
# 168 Tajikistan                Dushanbe                       68.7791      38.5358
# 169 North Macedonia           Skopje                         21.4333      42.0
# 170 Thailand                  Bangkok                        100.5252     13.722
# 171 East Timor                Dili                           125.5668     -8.5601
# 172 Togo                      Lome                           1.2123       6.1375
# 173 Tonga                     Nuku’alofa                     -175.2032    -21.1394
# 174 Trinidad and Tobago       Port-of-Spain                  -61.5166     10.6662
# 175 Tunisia                   Tunis                          10.1658      36.819
# 176 Turkey                    Ankara                         32.8543      39.9199
# 177 Turkmenistan              Ashgabat                       58.3833      37.95
# 178 Tuvalu                    Vaiaku village, Funafuti province 179.1991     -8.5189
# 179 Uganda                    Kampala                        32.5822      0.3163
# 180 Ukraine                   Kiev                           30.5186      50.4454
# 181 United Arab Emirates      Abu Dhabi                      54.3618      24.4648
# 182 United Kingdom            London                         -0.1257      51.5085
# 183 Tanzania                  Dar es Salaam; Dodoma (legislative) 35.7395      -6.1722
# 184 United States             Washington D.C.                -77.0364     38.8951
# 185 Uruguay                   Montevideo                     -56.1674     -34.8335
# 186 Uzbekistan                Tashkent                       69.2163      41.2647
# 187 Vanuatu                   Port-Vila                      168.3219     -17.7338
# 188 Venezuela                 Caracas                        -66.8792     10.488
# 189 Vietnam                   Hanoi                          105.8412     21.0245
# 190 Yemen                     Sanaa                          44.2078      15.3531
# 191 Zambia                    Lusaka                         28.2771      -15.4134
# 192 Zimbabwe                  Harare                         31.0539      -17.8294

# %% [markdown]
# Có nhiều quốc gia có nhiều thủ đô: thủ đô hành chính, thủ đô lập pháp, thủ đô tư pháp.
#
# Kiểm tra toạ độ trong bảng là của thành phố nào bằng API:
# https://api.api-ninjas.com/v1/geocoding?city={city}&country={Nauru}

# %%
lst_index_error = [20,40,118,120,158,161,178,183]
capital = ["La Paz","Abidjan","Yaren","Amsterdam","Cape Town","Colombo","Funafuti","Dodoma"]
dic_replace = {}
for i, idx in enumerate(lst_index_error):
    dic_replace[city_df.at[idx,"Capital"]] = capital[i]
dic_replace
# Out:
# {'La Paz (administrative); Sucre (judicial)': 'La Paz',
#  'Yamoussoukro (official); Abidjan (de facto)': 'Abidjan',
#  'no official capital; government offices in Yaren District': 'Yaren',
#  'Amsterdam; The Hague (seat of government)': 'Amsterdam',
#  'Pretoria (administrative); Cape Town (legislative); Bloemfontein (judiciary)': 'Cape Town',
#  'Colombo; Sri Jayewardenepura Kotte (legislative)': 'Colombo',
#  'Vaiaku village, Funafuti province': 'Funafuti',
#  'Dar es Salaam; Dodoma (legislative)': 'Dodoma'}

# %% [markdown]
# **KẾT LUẬN: Trong bước làm sạch, cần thay đổi City ở cả 2 bảng dữ liệu**

# %% [markdown]
# ### windspeed_10m

# %%
plt.figure(figsize=(8,3))
plt.boxplot(df.windspeed_10m, vert=False)
plt.xlabel("Tốc độ gió km/h")
plt.title("Biểu đồ hộp của windspeed_10m")
plt.show()

# %% [markdown]
# Vẫn có các cơn gió có tốc độ cao hơn. Mức ~100km/h là gió cấp 10, cấp 11
#
# **KẾT LUẬN: Không có windspeed_10m nào bất thường**

# %% [markdown]
# ## Logic

# %% [markdown]
# ### weathercode và cloudcover
# Khi **weathercode** = 0 hoặc 1 thì **cloudcover** phải thấp

# %%
# Dữ liệu có weathercode = 0
df_wc0 = df[['weathercode','cloudcover']][(df.weathercode == 0)]

cloudcover_0 = df_wc0.cloudcover.value_counts()
plt.bar(cloudcover_0.keys(),cloudcover_0);
plt.xlabel("% độ che phủ mây")
plt.ylabel("Số lượng bản ghi")
plt.title("Biểu đồ độ che phủ mây với weathercode = 0")
plt.show()

# %%
# Dữ liệu có weathercode = 1
df_wc1 = df[['weathercode','cloudcover']][(df.weathercode == 1)]
cloundcover1 = df_wc1.cloudcover.value_counts()
plt.bar(cloundcover1.keys(),cloundcover1);
plt.xlabel("% độ che phủ mây")
plt.ylabel("Số lượng bản ghi")
plt.title("Biểu đồ độ che phủ mây với weathercode = 1")
plt.show()

# %% [markdown]
# Giá trị weathercode = 0 thì cloudcover < 20%
#
# Giá trị weathercode = 1 thì cloudcover >= 20% và < 50%
#
# **Vậy weathercode và cloud không sai về logic**

# %% [markdown]
# ### precipitation

# %% [markdown]
# #### Với weathercode
#     + Mã 0: Thời tiết trong lành
#     + Mã 1: Mây mỏng hoặc ít mây
#     + Mã 2: Mây xám hoặc có mây
#     + Mã 3: Mây dày
#     + Mã 51: Có mưa
#     + Mã 53: Mưa rào
#     + Mã 55: Mưa đá
#     + Mã 61: Có tuyết
#     + Mã 63: Tuyết rơi
#     + Mã 71: Có sấm sét
#     + Mã 73: Sấm sét và mưa
#     + Mã 65: Sấm sét và tuyết
#     + Mã 75: Sấm sét và mưa đá

# %%
df.weathercode[df.precipitation > 0].value_counts().keys()
# Out:
# Int64Index([51, 53, 61, 55, 63, 71, 73, 65, 75], dtype='int64')

# %% [markdown]
# Tổng lượng nước > 0 khi có mưa (tức từ 51 trở lên)
#
# Tất cả đều là mã thời tiết đúng, không có 0,1,2,3.
#
# **KẾT LUẬN: Không có gì sai trong mối quan hệ precipitation và weathercode**

# %% [markdown]
# #### Với rain, snowfall
#
# Theo công thức thì precipitation = rain + snowfall/0.7

# %%
df_not_equal = df[['precipitation','rain','snowfall']]\
 [df.precipitation != round(df.rain + df.snowfall/0.7,1)]

# %%
df_not_equal
# Out:
#          precipitation  rain  snowfall
# 9                  0.0   0.0      0.07
# 10                 0.0   0.0      0.07
# 11                 0.0   0.0      0.07
# 24                 0.0   0.0      0.07
# 26                 0.0   0.0      0.07
# ...                ...   ...       ...
# 7491602            0.0   0.0      0.07
# 7492020            0.0   0.0      0.07
# 7497975            0.0   0.0      0.07
# 7498918            0.0   0.0      0.07
# 7498919            0.0   0.0      0.07
#
# [8170 rows x 3 columns]

# %% [markdown]
# Sai lệch có thể do cách làm tròn của 2 cột khác nhau .
#
# **KẾT LUẬN: Cần sửa các giá trị precipitation bị tính sai**

# %% [markdown]
# ### pressure_msl, surface_pressure và elevation
# Khi khu vực cao so với mực nước biển thì pressure_msl > surface_pressure và ngược lại

# %%
df.City[df.pressure_msl <= df.surface_pressure].value_counts()
# Out:
# Baku            40176
# Tarawa Atoll    40176
# Name: City, dtype: int64

# %%
city_df.Capital[city_df.elevation <= 0]
# Out:
# 10            Baku
# 88    Tarawa Atoll
# Name: Capital, dtype: object

# %% [markdown]
# 2 thành phố trên đúng là thấp hơn so với mực nước biển
#
# **KẾT LUẬN: Không sai về logic giữa pressure_msl, surface_pressure và elevation**

# %% [markdown]
# ### winddirection_10m
# Giá trị chỉ trong đoạn 0-359

# %%
df.winddirection_10m.min(),df.winddirection_10m.max()
# Out:
# (0, 360)

# %% [markdown]
# 2 điểm 0 và 360 bị trùng nhau.
#
# **KẾT LUẬN: Cần chuyển các giá trị winddirection_10m = 360 thành 0**

# %% [markdown]
# ### cloudcover
# Cần thuộc đoạn 0-100

# %%
df.cloudcover.min(), df.cloudcover.max()
# Out:
# (0, 100)

# %% [markdown]
# **KẾT LUẬN: cloudcover không sai logic**

# %% [markdown]
# ## Tổng kết các vấn đề
#
# **Có 4 vấn đề cần được làm sạch**
#
# - Cột time cần chuyển về datetime
# - City cần sửa lại tên và chọn giá trị duy nhất đúng với toạ độ
# - Cần chuyển các giá trị winddirection_10m = 360 thành 0
# - Cần sửa các giá trị precipitation bị tính sai

# %% [markdown]
# # Làm sạch dữ liệu
# ## time
# Chuyển về kiểu dữ liệu datetime

# %%
df.time = pd.to_datetime(df.time)

# %% [markdown]
# Tuy nhiên sau khi lưu file và đọc lại bằng pandas, Cột time sẽ không phải là datetime nữa

# %% [markdown]
# ## precipitation

# %%
df_2 = df.copy()
idx_precipitation_error = df_not_equal.index
def calculate_precipitation(row):
    return round(row['rain'] + row['snowfall']/0.7, 1)
df_2.loc[idx_precipitation_error, 'precipitation'] = df_2.loc[idx_precipitation_error].apply(calculate_precipitation, axis=1)

# %%
df_2[['precipitation','rain','snowfall']][df_2.precipitation != round(df_2.rain + (df_2.snowfall)/0.7,1)]
# Out:
# Empty DataFrame
# Columns: [precipitation, rain, snowfall]
# Index: []

# %% [markdown]
# ## winddirection_10m

# %%
idx_wind_error = df_2[df_2.winddirection_10m == 360].index
df_2.loc[idx_wind_error, 'winddirection_10m'] = df_2.loc[idx_wind_error].apply(lambda x:0, axis=1)

# %%
len(df_2[df_2.winddirection_10m == 360])
# Out:
# 0

# %% [markdown]
# ## City
# chuyển ở cả 2 bảng dữ liệu

# %%
city_df_copy = city_df.copy()
city_df_copy.Capital.replace(dic_replace, inplace = True)

# %%
df_2.City.replace(dic_replace, inplace = True)

# %% [markdown]
# # Lưu dữ liệu sau khi làm sạch

# %%
df_2.to_csv(path+"data_cleaned.csv", index=False)

# %%
city_df_copy.to_csv(path+"country_city_cleaned.csv", index=False)
